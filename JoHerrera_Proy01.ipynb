# %% [markdown]
# <a href="https://colab.research.google.com/github/WPNJoherrera/DATA-ANALYTICS/blob/Proyectos/JoHerrera_Proy01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto No 01 Alumno: Jose A. Herrera Sancho

# %% [markdown]
# #Ejercicio N°1:
#
#
# 1.   Escribir un programa que pregunte al usuario o genere las ventas de los últimos 5 días
# 2.   Muestre por pantalla una serie (Dataframe) con los datos de las ventas por producto (opcional): Nro de
# unidades y precio unitario
# 3. Indexada por los días, antes.
# 4. después de aplicarles un descuento del 5%.
#
# (Diversas opciones de solución: libre)

# %% [markdown]
# ### Puntos 1 y 2
# 1. Escribir un programa que pregunte al usuario o genere las
# ventas de los últimos 5 días.
# 2. Muestre por pantalla una serie (Dataframe) con los datos de las ventas por producto (opcional): Nro de
# unidades y precio unitario.

# %%
import pandas as pd
datos = { "fecha":["20240101", "20240102", "20240103", "20240104", "20240105"]
         ,"Prod":["Prod01", "Prod02", "Prod01", "Prod03", "Prod04"]
         ,"Precio":[100, 200, 100, 300, 400]
         ,"Cantidad":[5.5, 3, 2, 6, 7]
         }

dfVentas = pd.DataFrame(datos)

dfVentas
# Out:
#       fecha    Prod  Precio  Cantidad
# 0  20240101  Prod01     100       5.5
# 1  20240102  Prod02     200       3.0
# 2  20240103  Prod01     100       2.0
# 3  20240104  Prod03     300       6.0
# 4  20240105  Prod04     400       7.0

# %% [markdown]
# ### Punto 3
# 3. Indexada por los días, antes.

# %%
dfVentas.sort_values("Prod") #Desordeno proproducto
dfVentas
dfVentas.sort_values("fecha") #Ordeno por fecha



dfVentas['total vtas'] = dfVentas['Precio']*dfVentas['Cantidad']
dfVentas
# Out:
#       fecha    Prod  Precio  Cantidad  total vtas
# 0  20240101  Prod01     100       5.5       550.0
# 1  20240102  Prod02     200       3.0       600.0
# 2  20240103  Prod01     100       2.0       200.0
# 3  20240104  Prod03     300       6.0      1800.0
# 4  20240105  Prod04     400       7.0      2800.0

# %% [markdown]
# ### Punto 4
# 4. después de aplicarles un descuento del 5%

# %%
dfVentas['total vtas'] = dfVentas['Precio']*dfVentas['Cantidad']
dfVentas
# Out:
#       fecha    Prod  Precio  Cantidad  total vtas
# 0  20240101  Prod01     100       5.5       550.0
# 1  20240102  Prod02     200       3.0       600.0
# 2  20240103  Prod01     100       2.0       200.0
# 3  20240104  Prod03     300       6.0      1800.0
# 4  20240105  Prod04     400       7.0      2800.0

# %%
dfVentas['Descuento'] = dfVentas['total vtas']*(5/100)
dfVentas
# Out:
#       fecha    Prod  Precio  Cantidad  total vtas  Descuento
# 0  20240101  Prod01     100       5.5       550.0       27.5
# 1  20240102  Prod02     200       3.0       600.0       30.0
# 2  20240103  Prod01     100       2.0       200.0       10.0
# 3  20240104  Prod03     300       6.0      1800.0       90.0
# 4  20240105  Prod04     400       7.0      2800.0      140.0

# %%
dfVentas['Venta Neta'] = dfVentas['total vtas']-dfVentas['Descuento']
dfVentas
# Out:
#       fecha    Prod  Precio  Cantidad  total vtas  Descuento  Venta Neta
# 0  20240101  Prod01     100       5.5       550.0       27.5       522.5
# 1  20240102  Prod02     200       3.0       600.0       30.0       570.0
# 2  20240103  Prod01     100       2.0       200.0       10.0       190.0
# 3  20240104  Prod03     300       6.0      1800.0       90.0      1710.0
# 4  20240105  Prod04     400       7.0      2800.0      140.0      2660.0

# %% [markdown]
# #Ejercicio Nº 2
# 1.   Escribir un programa que reciba un diccionario con los ingresos mensuales de los clientes de una empresa.
# 2.   Devuelva una serie con el ingreso mínimo, máximo y media.
#
# El resultado final debe ser una serie con los estadísticos.

# %%
import pandas as pd

dicClientes = {'Cliente01' : 100,
               'Cliente02' : 110,
               'Cliente03' : 120,
               'Cliente04' : 130,
               'Cliente05' : 140,
               'Cliente06' : 150,
               'Cliente07' : 160,
               'Cliente08' : 170,
               'Cliente09' : 180,
               'Cliente10' : 190,
               'Cliente11' : 200,
               'Cliente11' : 210,
               'Cliente12' : 220,
               'Cliente13' : 230,
               'Cliente14' : 240
     }

serClientes = pd.Series(dicClientes)

List = [ serClientes.min(), serClientes.mean(), serClientes.max()  ]

SerStats = pd.Series( List, dtype = 'int' )

SerStats
# Out:
# 0    100.000000
# 1    167.857143
# 2    240.000000
# dtype: float64

# %% [markdown]
# #Ejercicio No 3
# Escribir programa que genere y muestre por pantalla un DataFrame con los datos de la siguiente tabla:

# %%
import pandas as pd
datosNo3 = { "MES":["Enero", "Febrero", "Marzo", "Abril", "Mayo"]
            ,"VENTAS":[30500, 35600, 28300, 33900, 42500]
            ,"GASTOS":[22000, 23450, 18100, 35700, 32450]
         }

dfVentas3 = pd.DataFrame(datosNo3)

dfVentas3
# Out:
#        MES  VENTAS  GASTOS
# 0    Enero   30500   22000
# 1  Febrero   35600   23450
# 2    Marzo   28300   18100
# 3    Abril   33900   35700
# 4     Mayo   42500   32450

# %% [markdown]
# ##1. Columna 1 = Gasto/Ventas*100.

# %%
dfVentas3["Columna 1"] = dfVentas3["GASTOS"] / dfVentas3["VENTAS"] * 100
dfVentas3
# Out:
#        MES  VENTAS  GASTOS   Columna 1
# 0    Enero   30500   22000   72.131148
# 1  Febrero   35600   23450   65.870787
# 2    Marzo   28300   18100   63.957597
# 3    Abril   33900   35700  105.309735
# 4     Mayo   42500   32450   76.352941

# %% [markdown]
# ##2. Columna 2 = Si Ventas>= 30000, imprimir “Meta Superada”, caso contrario imprimir “Meta no Superada”.

# %%
dfVentas3.loc[dfVentas3["VENTAS"] >= 30000, "Columna 2" ] = "Meta Superada"
dfVentas3.loc[dfVentas3["VENTAS"] < 30000, "Columna 2" ] = "Meta no Superada"
dfVentas3

##df.loc[df['set_of_numbers'] <= 4, 'equal_or_lower_than_4?'] = 'True'
# Out:
#        MES  VENTAS  GASTOS   Columna 1         Columna 2
# 0    Enero   30500   22000   72.131148     Meta Superada
# 1  Febrero   35600   23450   65.870787     Meta Superada
# 2    Marzo   28300   18100   63.957597  Meta no Superada
# 3    Abril   33900   35700  105.309735     Meta Superada
# 4     Mayo   42500   32450   76.352941     Meta Superada

# %% [markdown]
# ##Columna 3 = Si Gasto>Ventas, calcular el sobre gasto.

# %%
dfVentas3.loc[dfVentas3["GASTOS"] > dfVentas3["VENTAS"], "Columna 3" ] = dfVentas3["VENTAS"] / dfVentas3["GASTOS"] * 100
dfVentas3
# Out:
#        MES  VENTAS  GASTOS   Columna 1         Columna 2  Columna 3
# 0    Enero   30500   22000   72.131148     Meta Superada        NaN
# 1  Febrero   35600   23450   65.870787     Meta Superada        NaN
# 2    Marzo   28300   18100   63.957597  Meta no Superada        NaN
# 3    Abril   33900   35700  105.309735     Meta Superada  94.957983
# 4     Mayo   42500   32450   76.352941     Meta Superada        NaN

# %% [markdown]
# ##4. Obtener el total de las ventas de los últimos 3 meses

# %%
dfVentas3.tail(3)

dfVentas3.loc[ 2 : 4, ["VENTAS" ]].sum()
# Out:
# VENTAS    104700
# dtype: int64

# %% [markdown]
# ##Obtener el total de gastos de febrero a abril

# %%
dfVentas3.loc[ 1 : 3, ["GASTOS" ]].sum()
# Out:
# GASTOS    77250
# dtype: int64

# %% [markdown]
# #Ejercicio No 4
# Con el siguiente fichero datos_seguros.csv contiene información de riesgo de clientes de un banco. Escribir un programa con los siguientes requisitos:

# %% [markdown]
# ##1. Generar un DataFrame con los datos del fichero.

# %%
#cargamos la data desde nuestra PC
from google.colab import files
files.upload()

# %%
dfDSTSeguros = pd.read_csv('/content/datos_seguros.csv', sep=';') # sep=';'
dfDSTSeguros.head()
# Out:
#    MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0  201506             0              3.0           0.0        2300.0
# 1  201506             0              2.0        3215.0        3500.0
# 2  201506             0              1.0        3169.0        5000.0
# 3  201506             1              1.0        6495.0        8450.0
# 4  201506             0              NaN           NaN           NaN
#
#    USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  monto_ope_t2  \
# 0          0.000000                    0.0                 0.0         15.00
# 1          0.918571                    0.0                 0.0        548.98
# 2          0.633800                    0.0                 0.0          0.00
# 3          0.768639                    2.0               505.0       2137.94
# 4               NaN                    0.0                 0.0         12.37
#
#    PROM_ANUAL_MTO_OPERA  MAX_MTO_OPERA_Anual  Ratio_HospvsMtoTotal_t2 SEXO  \
# ...

# %%
dfDSTSeguros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45798 entries, 0 to 45797
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MES_T0                   45798 non-null  int64
#  1   VENTA_SEGURO             45798 non-null  int64
#  2   NUM_TC_TOTAL_T2          25397 non-null  float64
#  3   SALDO_BCO_T2             25452 non-null  float64
#  4   LINEA_BCO_T2             25452 non-null  float64
#  5   USO_LINEA_BCO_T2         25452 non-null  float64
#  6   Nro_CTa_Ahorro_Bco_T1    44405 non-null  float64
#  7   Ahorro_Sldo_Bco_T1       44405 non-null  float64
#  8   monto_ope_t2             32927 non-null  float64
#  9   PROM_ANUAL_MTO_OPERA     32927 non-null  float64
#  10  MAX_MTO_OPERA_Anual      32927 non-null  float64
#  11  Ratio_HospvsMtoTotal_t2  29719 non-null  float64
#  12  SEXO                     45798 non-null  object
#  13  ANTIGUEDAD_MES           45798 non-null  int64
# ...

# %% [markdown]
# ##

# %% [markdown]
# ##Mostrar las 10 primeras filas y las 10 últimas filas, verificar si tiene datos perdidos/nulos.

# %%
## 10 Primeras Filas

dfDSTSeguros.head(10)
# Out:
#    MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0  201506             0              3.0           0.0        2300.0
# 1  201506             0              2.0        3215.0        3500.0
# 2  201506             0              1.0        3169.0        5000.0
# 3  201506             1              1.0        6495.0        8450.0
# 4  201506             0              NaN           NaN           NaN
# 5  201506             0              3.0        2373.0        9373.0
# 6  201506             0              2.0           0.0           0.0
# 7  201506             0              1.0        3023.0       16720.0
# 8  201506             0              1.0        1931.0       12500.0
# 9  201506             0              NaN           NaN           NaN
#
#    USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  monto_ope_t2  \
# 0          0.000000                    0.0                 0.0         15.00
# ...

# %%
## 10 Primeras Filas

dfDSTSeguros.tail(10)
# Out:
#        MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 45788  201505             0              4.0           0.0           0.0
# 45789  201505             0              1.0           0.0           0.0
# 45790  201505             0              2.0           0.0           0.0
# 45791  201506             0              1.0           0.0           0.0
# 45792  201505             0              2.0           0.0       12000.0
# 45793  201505             0              2.0           0.0           0.0
# 45794  201505             0              NaN           NaN           NaN
# 45795  201506             0              NaN           NaN           NaN
# 45796  201506             0              NaN           NaN           NaN
# 45797  201506             0              1.0           0.0           0.0
#
#        USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  \
# 45788               0.0                    0.0                 0.0
# ...

# %%
## Verificar si tiene datos perdidos /nulos

pd.isna( dfDSTSeguros ).sum() ## Perdidos
# Out:
# MES_T0                         0
# VENTA_SEGURO                   0
# NUM_TC_TOTAL_T2            20401
# SALDO_BCO_T2               20346
# LINEA_BCO_T2               20346
# USO_LINEA_BCO_T2           20346
# Nro_CTa_Ahorro_Bco_T1       1393
# Ahorro_Sldo_Bco_T1          1393
# monto_ope_t2               12871
# PROM_ANUAL_MTO_OPERA       12871
# MAX_MTO_OPERA_Anual        12871
# Ratio_HospvsMtoTotal_t2    16079
# SEXO                           0
# ANTIGUEDAD_MES                 0
# DEPARTAMENTO                   0
# SOW_BCO_T2                     0
# SOW_BCO_SEMESTRAL              0
# dtype: int64

# %%
## Verificar si tiene datos perdidos /nulos

pd.isnull( dfDSTSeguros ).sum() ## Nulos
# Out:
# MES_T0                         0
# VENTA_SEGURO                   0
# NUM_TC_TOTAL_T2            20401
# SALDO_BCO_T2               20346
# LINEA_BCO_T2               20346
# USO_LINEA_BCO_T2           20346
# Nro_CTa_Ahorro_Bco_T1       1393
# Ahorro_Sldo_Bco_T1          1393
# monto_ope_t2               12871
# PROM_ANUAL_MTO_OPERA       12871
# MAX_MTO_OPERA_Anual        12871
# Ratio_HospvsMtoTotal_t2    16079
# SEXO                           0
# ANTIGUEDAD_MES                 0
# DEPARTAMENTO                   0
# SOW_BCO_T2                     0
# SOW_BCO_SEMESTRAL              0
# dtype: int64

# %% [markdown]
# ##Extraer las 1000 primeras filas y almacenarlas en un contenedor.

# %%
dfDstSegurosTop1000 = dfDSTSeguros.head(1000)
dfDstSegurosTop1000
# Out:
#      MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0    201506             0              3.0           0.0        2300.0
# 1    201506             0              2.0        3215.0        3500.0
# 2    201506             0              1.0        3169.0        5000.0
# 3    201506             1              1.0        6495.0        8450.0
# 4    201506             0              NaN           NaN           NaN
# ..      ...           ...              ...           ...           ...
# 995  201506             0              1.0        4357.0        4600.0
# 996  201506             0              NaN           NaN           NaN
# 997  201506             0              NaN           NaN           NaN
# 998  201506             0              1.0           0.0           0.0
# 999  201506             0              4.0           0.0           0.0
#
#      USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  \
# ...

# %%
dfDstSegurosTop1000.to_csv("dfDstSegurosTop1000.csv", sep = ";" )
